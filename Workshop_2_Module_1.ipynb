# %% [markdown]
# <a href="https://colab.research.google.com/github/nzungizelab/-Microbiome-Data-Analysis-using-Deep-Learning/blob/NzungizeL/Workshop_2_Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Workshop 2 module 1 [here](https://anopheles-genomic-surveillance.github.io/workshop-2/module-1-pandas.html)

# %%
#malariagen_data package so we have easy access to some genomic data
# !pip install -q --no-warn-conflicts malariagen_data
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 679.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 60.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 37.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.5/302.5 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 685.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 3.4 MB/s eta 0:00:00
# ...

# %%
#import the malariagen_data and pandas packages.
import malariagen_data
import pandas as pd

# %%
# access to MalariaGEN Ag3.0 data resource
ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release/
# Data releases available : 3.0
# Results cache           : None
# Cohorts analysis        : 20230516
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.12.0
# Client location         : Washington, D.C., US
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %%
# set a df
df_samples = ag3.sample_metadata(sample_sets="3.0")
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
# ...

# %%
# check type of data
type(df_samples)
# Out:
# pandas.core.frame.DataFrame

# %%
#explorer the df
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
# ...

# %%
#genome annotations
df_geneset = ag3.geneset()
df_geneset
# Out:
#             contig      source             type   start       end  score  \
# 0               2L  VectorBase       chromosome       1  49364325    NaN
# 1               2L  VectorBase             gene  157348    186936    NaN
# 2               2L  VectorBase             mRNA  157348    181305    NaN
# 3               2L  VectorBase  three_prime_UTR  157348    157495    NaN
# 4               2L  VectorBase             exon  157348    157623    NaN
# ...            ...         ...              ...     ...       ...    ...
# 196140  Y_unplaced  VectorBase   five_prime_UTR   47932     48111    NaN
# 196141  Y_unplaced  VectorBase             exon   47932     48138    NaN
# 196142  Y_unplaced  VectorBase              CDS   48112     48138    NaN
# 196143  Y_unplaced  VectorBase             exon   48301     48385    NaN
# 196144  Y_unplaced  VectorBase              CDS   48301     48385    NaN
#
#        strand  phase             ID         Parent              Name  \
# ...

# %%
# check NSNP using SNP allele frequencies()
snp_freqs_df = ag3.snp_allele_frequencies(
    transcript="AGAP004707-RD",
    cohorts="admin1_year",
    sample_sets=["AG1000G-BF-A", "AG1000G-BF-B", "AG1000G-BF-C"],
)
snp_freqs_df
# Out:
# ...
# Compute SNP effects:   0%|          | 0/9675 [00:00<?, ?it/s]
#                                                  pass_gamb_colu_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                      True
#        2358328  T          C          NaN                       True
#        2358441  A          T          NaN                       True
#        2358468  A          C          NaN                       True
#        2358581  T          A          NaN                       True
# ...                                                              ...
#        2431424  G          T          G2055V                    True
#        2431518  C          A          A2086A                    True
#        2431527  G          C          V2089V                    True
#        2431569  C          A          V2103V                    True
#        2431613  T          C          V2118A                    True
#
# ...

# %%
#reading from a CSV file from driver documents (sample_data)
df_housing = pd.read_csv("sample_data/california_housing_train.csv")
df_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#creating a DataFrame from scratch
df_hitchhikers = pd.DataFrame(data={
    "name": ["Arthur Dent", "Tricia McMillan", "Ford Prefect", "Zaphod Beeblebrox", "Marvin the Paranoid Android"],
    "taxon": ["human", "human", "betelgeusian", "betelgeusian", "robot"],
    "gender": ["male", "female", "male", "male", None],
    "number_of_heads": [1, 1, 2, 2, 1],
    "intelligence": [100, 180, 120, 30, 5_000_000]
})
df_hitchhikers
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                2
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %%
#Structure of a DataFrame
#df contain rows and columns. therefore each df also has an index, which is a special column
# %%html
<img width="90%" height="90%"src="https://storage.googleapis.com/vo_agam_release/reference/training-images/workshop-2/W2M1-1.PNG"/>
# Out:
# <img width="90%" height="90%"src="https://storage.googleapis.com/vo_agam_release/reference/training-images/workshop-2/W2M1-1.PNG"/>

# %%
#Counting rows and columns
num_rows = len(df_hitchhikers)
num_rows
# Out:
# 5

# %%
num_row1 = len(df_housing)
num_row1
# Out:
# 17000

# %%
# counting rows
num_rows2 = len(df_geneset)
num_rows2
# Out:
# 196145

# %%
# count num of col
num_cols = len(df_hitchhikers.columns)
num_cols
# Out:
# 5

# %%
num_cols1 = len(df_housing.columns)
num_cols1
# Out:
# 9

# %%
num_cols2 = len(df_geneset.columns)
num_cols2
# Out:
# 12

# %%
# check the col names
col_names = list(df_hitchhikers.columns)
col_names
# Out:
# ['name', 'taxon', 'gender', 'number_of_heads', 'intelligence']

# %%
col_names1 = list(df_geneset.columns)
col_names1
# Out:
# ['contig',
#  'source',
#  'type',
#  'start',
#  'end',
#  'score',
#  'strand',
#  'phase',
#  'ID',
#  'Parent',
#  'Name',
#  'description']

# %%
col_names2 = list(df_housing)
col_names2
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
# access on one column or row from a df
character_name = df_hitchhikers["name"]
character_name
# Out:
# 0                    Arthur Dent
# 1                Tricia McMillan
# 2                   Ford Prefect
# 3              Zaphod Beeblebrox
# 4    Marvin the Paranoid Android
# Name: name, dtype: object

# %%
character_name1 = df_geneset['contig']
character_name1
# Out:
# 0                 2L
# 1                 2L
# 2                 2L
# 3                 2L
# 4                 2L
#              ...
# 196140    Y_unplaced
# 196141    Y_unplaced
# 196142    Y_unplaced
# 196143    Y_unplaced
# 196144    Y_unplaced
# Name: contig, Length: 196145, dtype: object

# %%
type(character_name)
# Out:
# pandas.core.series.Series

# %%
character_taxon = df_hitchhikers["taxon"]
character_taxon.value_counts()
# Out:
# human           2
# betelgeusian    2
# robot           1
# Name: taxon, dtype: int64

# %%
#under pandas  describe() function can be useful for investigating numerical data.
character_heads = df_hitchhikers["number_of_heads"]
character_heads.describe()

#The mean number of heads is 1.4
#df have at least (min) 1 and at most (max) 2 heads
# Out:
# count    5.000000
# mean     1.400000
# std      0.547723
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000
# Name: number_of_heads, dtype: float64

# %%
#check the name of col in df_samples
col_names2 = list(df_samples)
col_names2
# Out:
# ['sample_id',
#  'partner_sample_id',
#  'contributor',
#  'country',
#  'location',
#  'year',
#  'month',
#  'latitude',
#  'longitude',
#  'sex_call',
#  'sample_set',
#  'release',
#  'quarter',
#  'aim_species_fraction_arab',
#  'aim_species_fraction_colu',
#  'aim_species_fraction_colu_no2l',
#  'aim_species_gambcolu_arabiensis',
#  'aim_species_gambiae_coluzzii',
#  'aim_species',
#  'country_iso',
#  'admin1_name',
#  'admin1_iso',
#  'admin2_name',
#  'taxon',
#  'cohort_admin1_year',
#  'cohort_admin1_month',
#  'cohort_admin1_quarter',
#  'cohort_admin2_year',
#  'cohort_admin2_month',
#  'cohort_admin2_quarter']

# %%
#Access the “country” column from the df_samples to check the number of mosquito samples from each country.
character_name1 = df_samples["country"].value_counts()
character_name1
# Out:
# Cameroon                            444
# Tanzania                            300
# Lab Cross                           297
# Burkina Faso                        296
# Uganda                              290
# Gambia, The                         279
# Mali                                225
# Guinea                              136
# Guinea-Bissau                       101
# Ghana                               100
# Kenya                                86
# Angola                               81
# Cote d'Ivoire                        80
# Democratic Republic of the Congo     76
# Mozambique                           74
# Central African Republic             73
# Gabon                                69
# Malawi                               41
# Mayotte                              23
# Equatorial Guinea                    10
# Name: country, dtype: int64

# %%
#check the name under df_geneset
col_names3 = list(df_geneset)
col_names3
# Out:
# ['contig',
#  'source',
#  'type',
#  'start',
#  'end',
#  'score',
#  'strand',
#  'phase',
#  'ID',
#  'Parent',
#  'Name',
#  'description']

# %%
# check the number of genome annotations of different types using values_count()
character_names3 = df_geneset['type'].value_counts()
character_names3
# Out:
# exon                      72257
# CDS                       66103
# five_prime_UTR            16598
# mRNA                      14979
# gene                      13057
# three_prime_UTR           11665
# ncRNA_gene                  729
# tRNA                        362
# rRNA                        242
# pre_miRNA                    77
# snRNA                        35
# pseudogene                   10
# pseudogenic_transcript       10
# chromosome                    8
# ncRNA                         4
# SRP_RNA                       3
# snoRNA                        2
# lnc_RNA                       2
# RNase_MRP_RNA                 1
# RNase_P_RNA                   1
# Name: type, dtype: int64

# %%
#check col under snp_freqs_df
col_names4 = list(snp_freqs_df)
col_names4
# Out:
# ['pass_gamb_colu_arab',
#  'pass_gamb_colu',
#  'pass_arab',
#  'frq_BF-07_gamb_2004',
#  'frq_BF-09_colu_2012',
#  'frq_BF-09_colu_2014',
#  'frq_BF-09_gamb_2012',
#  'frq_BF-09_gamb_2014',
#  'max_af',
#  'transcript',
#  'effect',
#  'impact',
#  'ref_codon',
#  'alt_codon',
#  'aa_pos',
#  'ref_aa',
#  'alt_aa',
#  'label']

# %%
# check the number of SNPs with different effects under snp_freqs_df
character_name4 = snp_freqs_df['effect']
character_name4
# Out:
# contig  position  ref_allele  alt_allele  aa_change
# 2L      2358252   C           T           A32V         NON_SYNONYMOUS_CODING
#         2358328   T           C           NaN                       INTRONIC
#         2358441   A           T           NaN                       INTRONIC
#         2358468   A           C           NaN                       INTRONIC
#         2358581   T           A           NaN                       INTRONIC
#                                                                ...
#         2431424   G           T           G2055V       NON_SYNONYMOUS_CODING
#         2431518   C           A           A2086A           SYNONYMOUS_CODING
#         2431527   G           C           V2089V           SYNONYMOUS_CODING
#         2431569   C           A           V2103V           SYNONYMOUS_CODING
#         2431613   T           C           V2118A       NON_SYNONYMOUS_CODING
# Name: effect, Length: 9675, dtype: object

# %%
#chekc col under df_hitchhikers
col_names5 =list(df_hitchhikers)
col_names5
# Out:
# ['name', 'taxon', 'gender', 'number_of_heads', 'intelligence']

# %%
#Then Access on multiple columns under df_hitchhikers
# provide the column names as a list of strings
selected_cols = ["name", "taxon", "number_of_heads"]
df_hh = df_hitchhikers[selected_cols]
df_hh
# Out:
#                           name         taxon  number_of_heads
# 0                  Arthur Dent         human                1
# 1              Tricia McMillan         human                1
# 2                 Ford Prefect  betelgeusian                2
# 3            Zaphod Beeblebrox  betelgeusian                2
# 4  Marvin the Paranoid Android         robot                1

# %%
#second option
#You can also put the list of columns directly inside the square brackets
df_hh = df_hitchhikers[["name", "taxon", "number_of_heads"]]
df_hh
# Out:
#                           name         taxon  number_of_heads
# 0                  Arthur Dent         human                1
# 1              Tricia McMillan         human                1
# 2                 Ford Prefect  betelgeusian                2
# 3            Zaphod Beeblebrox  betelgeusian                2
# 4  Marvin the Paranoid Android         robot                1

# %%
#Create a new DataFrame containing only the “sample_id”, “country” and “year” columns from the df_samples
df_hh1 = df_samples[['sample_id', 'country', 'year']]
df_hh1
# Out:
#      sample_id    country  year
# 0     AR0047-C     Angola  2009
# 1     AR0049-C     Angola  2009
# 2     AR0051-C     Angola  2009
# 3     AR0061-C     Angola  2009
# 4     AR0078-C     Angola  2009
# ...        ...        ...   ...
# 3076  AD0494-C  Lab Cross    -1
# 3077  AD0495-C  Lab Cross    -1
# 3078  AD0496-C  Lab Cross    -1
# 3079  AD0497-C  Lab Cross    -1
# 3080  AD0498-C  Lab Cross    -1
#
# [3081 rows x 3 columns]

# %%
# Create a new DataFrame containing only the “ID”, “contig”, “start” and “end” columns from the df_geneset
df_hh2 = df_geneset[['ID', 'contig', 'start', 'end']]
df_hh2
# Out:
#                    ID      contig   start       end
# 0                  2L          2L       1  49364325
# 1          AGAP004677          2L  157348    186936
# 2       AGAP004677-RA          2L  157348    181305
# 3                 NaN          2L  157348    157495
# 4                 NaN          2L  157348    157623
# ...               ...         ...     ...       ...
# 196140            NaN  Y_unplaced   47932     48111
# 196141            NaN  Y_unplaced   47932     48138
# 196142  AGAP029375-PA  Y_unplaced   48112     48138
# 196143            NaN  Y_unplaced   48301     48385
# 196144  AGAP029375-PA  Y_unplaced   48301     48385
#
# [196145 rows x 4 columns]
